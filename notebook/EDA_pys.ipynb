# %% [markdown]
# <a href="https://colab.research.google.com/github/y001003/medistream-recsys-project/blob/main/notebook/EDA_pys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Medistream EDA

# %% [markdown]
# ## 1. Import and load data

# %%
import pandas as pd
import numpy as nb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## colab 환경에서 실행
articles = pd.read_csv("/content/drive/MyDrive/data/medistream/articles.csv")
orders = pd.read_csv("/content/drive/MyDrive/data/medistream/orders.csv")
products = pd.read_csv("/content/drive/MyDrive/data/medistream/products.csv")
crawling1 = pd.read_csv("/content/drive/MyDrive/data/medistream/crawling_data_csv/jsakommall_t.csv")
crawling2 = pd.read_csv("/content/drive/MyDrive/data/medistream/crawling_data_csv/jsanjinmed_t.csv")
crawling3 = pd.read_csv("/content/drive/MyDrive/data/medistream/crawling_data_csv/jshanemall_t.csv")
crawling4 = pd.read_csv("/content/drive/MyDrive/data/medistream/crawling_data_csv/jshanpuremall_t.csv")
crawling5 = pd.read_csv("/content/drive/MyDrive/data/medistream/crawling_data_csv/jshumanherb_t.csv")
crawling6 = pd.read_csv("/content/drive/MyDrive/data/medistream/crawling_data_csv/jskmmall_t.csv")
crawling7 = pd.read_csv("/content/drive/MyDrive/data/medistream/crawling_data_csv/jsoneshop_t.csv")

# %%
## local 환경에서 실행
# articles = pd.read_csv("../data/articles.csv")
# orders = pd.read_csv("../data/orders.csv")
# products = pd.read_csv("../data/products.csv")
# crawling1 = pd.read_csv("../data/crawling_data_csv/jsakommall_t.csv")
# crawling2 = pd.read_csv("../data/crawling_data_csv/jsanjinmed_t.csv")
# crawling3 = pd.read_csv("../data/crawling_data_csv/jshanemall_t.csv")
# crawling4 = pd.read_csv("../data/crawling_data_csv/jshanpuremall_t.csv")
# crawling5 = pd.read_csv("../data/crawling_data_csv/jshumanherb_t.csv")
# crawling6 = pd.read_csv("../data/crawling_data_csv/jskmmall_t.csv")
# crawling7 = pd.read_csv("../data/crawling_data_csv/jsoneshop_t.csv")
# Out:
# C:\Users\y0010\AppData\Local\Temp\ipykernel_22124\541759349.py:1: DtypeWarning: Columns (14,15,23,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   articles = pd.read_csv("../data/articles.csv")
# C:\Users\y0010\AppData\Local\Temp\ipykernel_22124\541759349.py:2: DtypeWarning: Columns (5,7,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   orders = pd.read_csv("../data/orders.csv")

# %%
# 아티클, 구매 데이터, 제품 데이터, 유저주문 데이터
articles.shape, orders.shape,products.shape,crawling1.shape,crawling2.shape,crawling3.shape,crawling4.shape,crawling5.shape,crawling6.shape,crawling7.shape
# Out:
# ((50191, 37),
#  (206689, 36),
#  (5142, 38),
#  (6108, 20),
#  (6203, 19),
#  (9910, 20),
#  (585, 19),
#  (559, 20),
#  (14262, 20),
#  (9331, 20))

# %%
articles_df= pd.DataFrame(articles).iloc[:,1:]
orders_df = pd.DataFrame(orders).iloc[:,1:]
products_df = pd.DataFrame(products).iloc[:,1:]

# %% [markdown]
# ## 2. Preprocessing and EDA

# %%
articles_df
# Out:
#           ID BOARD_URI_NAME WRITER_TYPE  \
# 0          1   Announcement    REALNAME
# 1          5         MeetUp    REALNAME
# 2          8         MeetUp    REALNAME
# 3          9         MeetUp    REALNAME
# 4         10         MeetUp    REALNAME
# ...      ...            ...         ...
# 50186  54497           Test    REALNAME
# 50187  54498      KMDForest       ANONY
# 50188  54499      KMDForest       ANONY
# 50189  54500      KMDForest       ANONY
# 50190  54501           Test    REALNAME
#
#                                                   SHA_ID ANONY_HASH  \
# 0      4e4e709b8bd5a923a0e26bfe221f75dbd9f7efd875d93d...        NaN
# 1      d63a1f1da4384bf48b4a48502bbf68a860a571fb56c0c1...        NaN
# 2      d63a1f1da4384bf48b4a48502bbf68a860a571fb56c0c1...        NaN
# 3      d63a1f1da4384bf48b4a48502bbf68a860a571fb56c0c1...        NaN
# 4      d63a1f1da4384bf48b4a48502bbf68a860a571fb56c0c1...        NaN
# ...
